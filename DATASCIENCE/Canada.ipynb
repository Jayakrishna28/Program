# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("C:/Users/LENOVO/OneDrive/Documents/CODING/DATA SCIENCE/Datasets/canada_per_capita_income (1).csv")
df.head(10)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
# 5  1975              5998.144346
# 6  1976              7062.131392
# 7  1977              7100.126170
# 8  1978              7247.967035
# 9  1979              7602.912681

# %%
# %matplotlib inline
plt.title("Canada's PCI") 
plt.xlabel("AREA")
plt.ylabel("PER CAPITA INCOME")
plt.scatter(df['year'],df['per capita income (US$)'],color='green')

# %%
x=df[['year']]

# %%
y=df['per capita income (US$)']

# %%
reg = linear_model.LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
