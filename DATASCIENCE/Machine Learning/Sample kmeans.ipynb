# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Sample 2D data
X = np.random.rand(100, 2)  # 100 points in 2D space
X
# Out:
# array([[0.43072533, 0.02978276],
#        [0.73878192, 0.16627046],
#        [0.31543637, 0.72469527],
#        [0.25341307, 0.49782546],
#        [0.83026195, 0.44315816],
#        [0.62338336, 0.8015815 ],
#        [0.28575941, 0.19840567],
#        [0.02257782, 0.84673548],
#        [0.13922903, 0.54498604],
#        [0.39314235, 0.14162416],
#        [0.96465557, 0.09901843],
#        [0.69733   , 0.97986389],
#        [0.45109296, 0.40172849],
#        [0.97057897, 0.15589803],
#        [0.03627348, 0.54859669],
#        [0.14764912, 0.89249079],
#        [0.61931072, 0.6424309 ],
#        [0.99193415, 0.36786485],
#        [0.27747248, 0.33545467],
#        [0.81395397, 0.81004489],
#        [0.87319179, 0.79123996],
#        [0.27215365, 0.06583624],
#        [0.06238627, 0.69474793],
#        [0.42273043, 0.69855523],
#        [0.69621642, 0.36845318],
#        [0.51182098, 0.64453854],
#        [0.72806025, 0.54440445],
#        [0.48146126, 0.44500118],
#        [0.59362791, 0.09092212],
#        [0.05794119, 0.79026097],
#        [0.33202932, 0.00248153],
#        [0.54407225, 0.68710425],
#        [0.06357218, 0.12759542],
#        [0.08058225, 0.27557876],
#        [0.28847706, 0.60233049],
#        [0.26356526, 0.44556166],
#        [0.00703366, 0.20400283],
#        [0.74264959, 0.48862102],
#        [0.80660957, 0.39925964],
#        [0.46217138, 0.39154728],
#        [0.69102265, 0.52691674],
#        [0.9526326 , 0.5020034 ],
#        [0.73137132, 0.44391179],
#        [0.28203107, 0.28094881],
#        [0.5144923 , 0.74294531],
#        [0.87804246, 0.55076241],
#        [0.08775165, 0.20080627],
#        [0.48343247, 0.16896141],
#        [0.29541362, 0.88574705],
#        [0.0475921 , 0.33203796],
#        [0.1056509 , 0.13805886],
#        [0.6048588 , 0.60639254],
#        [0.74567588, 0.06114887],
#        [0.41738144, 0.12921945],
#        [0.36131214, 0.7258276 ],
#        [0.32544435, 0.7090605 ],
#        [0.73264807, 0.14070493],
#        [0.78695396, 0.41983025],
#        [0.39597797, 0.04748038],
#        [0.81887778, 0.56385383],
#        [0.76088934, 0.58511432],
#        [0.59166029, 0.70777484],
#        [0.90231486, 0.13818713],
#        [0.8861948 , 0.87568869],
#        [0.40134347, 0.11711683],
#        [0.79607204, 0.57103847],
#        [0.77483211, 0.53558573],
#        [0.305822  , 0.9917963 ],
#        [0.38130897, 0.08835673],
#        [0.27478025, 0.33502326],
#        [0.84968857, 0.97745329],
#        [0.4336694 , 0.93703958],
#        [0.09559501, 0.07701609],
#        [0.46886836, 0.77145667],
#        [0.11218942, 0.52770217],
#        [0.5459448 , 0.29479364],
#        [0.87112884, 0.29094369],
#        [0.92751679, 0.34911178],
#        [0.77461954, 0.17204406],
#        [0.16572132, 0.30754556],
#        [0.19094935, 0.80336307],
#        [0.19243381, 0.71998523],
#        [0.67151687, 0.87411313],
#        [0.9913637 , 0.02219817],
#        [0.89778928, 0.46876026],
#        [0.68637034, 0.91577906],
#        [0.4383401 , 0.3946267 ],
#        [0.21473875, 0.05658331],
#        [0.76490913, 0.48810709],
#        [0.38592927, 0.94153706],
#        [0.94424161, 0.05199904],
#        [0.99249949, 0.84439701],
#        [0.77663326, 0.55215971],
#        [0.39798575, 0.07081271],
#        [0.47870507, 0.99453558],
#        [0.81094784, 0.6101606 ],
#        [0.09685432, 0.23990634],
#        [0.79664963, 0.10126299],
#        [0.85611381, 0.20948891],
#        [0.9442222 , 0.8085333 ]])

# %%
# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
# Get cluster centers (this should be 2D: (n_clusters, 2))
centers = kmeans.cluster_centers_
centers
# Out:
# array([[0.27908356, 0.24439793],
#        [0.83683938, 0.41940936],
#        [0.41679465, 0.79679079]])

# %%
# Scatter plot of data points
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)

# Plot cluster centers
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200, label='Centers')

plt.legend()
plt.title("K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
